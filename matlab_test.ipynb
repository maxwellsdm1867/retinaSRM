% %%
a = 1;

% %%
test_noise_generator
% Out:
% === Random Noise Generator Test ===
%
% 1. Generating Gaussian noise...
%    Mean: -0.033, Std: 0.999
% 2. Generating uniform noise...
%    Min: -1.999, Max: 1.998
% 3. Generating Poisson noise...
%    Mean: 5.043
% 4. Generating exponential noise...
%    Mean: 0.540
% 5. Generating salt and pepper noise...
%    Noise density: 2.5%
% 6. Generating speckle noise...
%    Mean: 1.000, Std: 0.313
%
% === Test completed successfully! ===
% Check the generated figure for visualizations.
%
% === Additional Usage Examples ===
%
% Signal processing examples completed!
